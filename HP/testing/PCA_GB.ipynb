# %%
import pandas as pd

dataset = pd.read_csv('Phising_Training_Dataset.csv')

ds = dataset.iloc[:, 1:32] 
# print(ds.iloc[:, 30:])
ds.iloc[:, 30:].replace(-1,0,inplace=True)
# print(ds.iloc[:, 30:])


x = dataset.iloc[:, 1:31].values
y = dataset.iloc[:, 31:].values

# print(x.shape, y.shape)

for i in y:
    if i[0] == -1:
        i[0] = 0

corr = ds.corr()
print(corr)
# Out:
#                              having_IP  URL_Length  Shortining_Service  \
# having_IP                     1.000000   -0.053184            0.399121
# URL_Length                   -0.053184    1.000000           -0.102147
# Shortining_Service            0.399121   -0.102147            1.000000
# having_At_Symbol              0.162727   -0.070171            0.112393
# double_slash_redirecting      0.388331   -0.083623            0.841223
# Prefix_Suffix                -0.010055    0.053664           -0.088494
# having_Sub_Domain            -0.083055   -0.004870           -0.033567
# SSLfinal_State                0.071759    0.048650           -0.061707
# Domain_registeration_length  -0.024847   -0.221207            0.055415
# Favicon                       0.086203   -0.046556            0.005180
# port                          0.065463   -0.000149           -0.001731
# HTTPS_token                   0.346835   -0.095062            0.751194
# Request_URL                   0.032203    0.244441           -0.035202
# URL_of_Anchor                 0.103445   -0.028365            0.004144
# Links_in_tags                -0.004489    0.051372           -0.139200
# SFH                          -0.012995    0.404926           -0.026090
# Submitting_to_email           0.075712   -0.015684            0.048770
# Abnormal_URL                  0.322580   -0.109873            0.734771
# Redirect                     -0.299680    0.045777           -0.494392
# on_mouseover                  0.100507   -0.052842            0.070095
# RightClick                    0.058687   -0.019104            0.034852
# popUpWidnow                   0.096831   -0.055383            0.038871
# Iframe                        0.074897   -0.020666            0.016820
# age_of_domain                 0.010264    0.197745           -0.053322
# DNSRecord                    -0.059877   -0.046371            0.441312
# web_traffic                   0.013970    0.017214           -0.054722
# Page_Rank                    -0.088005    0.160600            0.027620
# Google_Index                  0.042025    0.000906            0.191166
# Links_pointing_to_page       -0.339673   -0.023217           -0.190125
# Statistical_report           -0.020243   -0.076373            0.096561
# Result                        0.094027    0.059331           -0.066170
#
#                              having_At_Symbol  double_slash_redirecting  \
# having_IP                            0.162727                  0.388331
# URL_Length                          -0.070171                 -0.083623
# Shortining_Service                   0.112393                  0.841223
# having_At_Symbol                     1.000000                  0.091817
# double_slash_redirecting             0.091817                  1.000000
# Prefix_Suffix                       -0.011074                 -0.093561
# having_Sub_Domain                   -0.056443                 -0.032389
# SSLfinal_State                       0.031472                 -0.036930
# Domain_registeration_length          0.019944                  0.043198
# Favicon                              0.320858                  0.037648
# port                                 0.389837                  0.023906
# HTTPS_token                          0.105202                  0.752510
# Request_URL                          0.026982                 -0.023427
# URL_of_Anchor                        0.062111                 -0.002841
# Links_in_tags                       -0.078456                 -0.132653
# SFH                                 -0.009287                 -0.047335
# Submitting_to_email                  0.387511                  0.030909
# Abnormal_URL                         0.212192                  0.717434
# Redirect                            -0.025748                 -0.554337
# on_mouseover                         0.311913                  0.097400
# RightClick                           0.257179                  0.023054
# popUpWidnow                          0.307084                  0.058287
# Iframe                               0.319482                  0.009779
# age_of_domain                       -0.011848                 -0.047033
# DNSRecord                           -0.040347                  0.433107
# web_traffic                          0.035172                 -0.073786
# Page_Rank                           -0.048638                  0.009250
# Google_Index                         0.052266                  0.216002
# Links_pointing_to_page              -0.021183                 -0.185197
# Statistical_report                  -0.086436                  0.081190
# Result                               0.050045                 -0.037758
#
#                              Prefix_Suffix  having_Sub_Domain  SSLfinal_State  \
# having_IP                        -0.010055          -0.083055        0.071759
# URL_Length                        0.053664          -0.004870        0.048650
# Shortining_Service               -0.088494          -0.033567       -0.061707
# having_At_Symbol                 -0.011074          -0.056443        0.031472
# double_slash_redirecting         -0.093561          -0.032389       -0.036930
# Prefix_Suffix                     1.000000           0.087054        0.258982
# having_Sub_Domain                 0.087054           1.000000        0.265866
# SSLfinal_State                    0.258982           0.265866        1.000000
# Domain_registeration_length      -0.094592          -0.087432       -0.187539
# Favicon                          -0.005699          -0.016026       -0.019725
# port                             -0.024500           0.004470        0.024495
# HTTPS_token                      -0.075264          -0.025517       -0.023252
# Request_URL                       0.096219           0.103016        0.190500
# URL_of_Anchor                     0.348929           0.225146        0.540123
# Links_in_tags                     0.098991           0.087959        0.168650
# SFH                               0.003991           0.088461        0.167303
# Submitting_to_email              -0.050733           0.010933        0.002112
# Abnormal_URL                     -0.086667          -0.025826       -0.045735
# Redirect                          0.018698           0.026559       -0.025875
# on_mouseover                      0.018127          -0.025532        0.020442
# RightClick                       -0.029651           0.010255        0.007350
# popUpWidnow                      -0.012412          -0.026657       -0.017061
# Iframe                           -0.035630           0.005246       -0.013408
# age_of_domain                     0.074091           0.114317        0.170103
# DNSRecord                        -0.008066           0.132470        0.053233
# web_traffic                       0.112270          -0.001427        0.267394
# Page_Rank                        -0.010107           0.130962        0.070730
# Google_Index                      0.059577           0.059754        0.092084
# Links_pointing_to_page            0.063379          -0.002065       -0.006427
# Statistical_report               -0.014781           0.086271        0.048559
# Result                            0.344660           0.296728        0.712543
#
#                              Domain_registeration_length   Favicon  ...  \
# having_IP                                      -0.024847  0.086203  ...
# URL_Length                                     -0.221207 -0.046556  ...
# Shortining_Service                              0.055415  0.005180  ...
# having_At_Symbol                                0.019944  0.320858  ...
# double_slash_redirecting                        0.043198  0.037648  ...
# Prefix_Suffix                                  -0.094592 -0.005699  ...
# having_Sub_Domain                              -0.087432 -0.016026  ...
# SSLfinal_State                                 -0.187539 -0.019725  ...
# Domain_registeration_length                     1.000000  0.061075  ...
# Favicon                                         0.061075  1.000000  ...
# port                                            0.028800  0.791200  ...
# HTTPS_token                                     0.054054  0.044693  ...
# Request_URL                                    -0.604203 -0.007760  ...
# URL_of_Anchor                                  -0.158990  0.035219  ...
# Links_in_tags                                  -0.097145 -0.099148  ...
# SFH                                            -0.133333 -0.016926  ...
# Submitting_to_email                             0.046016  0.648181  ...
# Abnormal_URL                                    0.049472  0.075323  ...
# Redirect                                       -0.007021 -0.017840  ...
# on_mouseover                                    0.028866  0.683005  ...
# RightClick                                      0.023938  0.400239  ...
# popUpWidnow                                     0.059220  0.937124  ...
# Iframe                                          0.011737  0.602297  ...
# age_of_domain                                  -0.075671 -0.007488  ...
# DNSRecord                                      -0.017232  0.090112  ...
# web_traffic                                    -0.140463 -0.046961  ...
# Page_Rank                                      -0.050998  0.009195  ...
# Google_Index                                   -0.035604 -0.011916  ...
# Links_pointing_to_page                          0.130958 -0.124347  ...
# Statistical_report                              0.006768  0.271378  ...
# Result                                         -0.219960 -0.003260  ...
#
#                              popUpWidnow    Iframe  age_of_domain  DNSRecord  \
# having_IP                       0.096831  0.074897       0.010264  -0.059877
# URL_Length                     -0.055383 -0.020666       0.197745  -0.046371
# Shortining_Service              0.038871  0.016820      -0.053322   0.441312
# having_At_Symbol                0.307084  0.319482      -0.011848  -0.040347
# double_slash_redirecting        0.058287  0.009779      -0.047033   0.433107
# Prefix_Suffix                  -0.012412 -0.035630       0.074091  -0.008066
# having_Sub_Domain              -0.026657  0.005246       0.114317   0.132470
# SSLfinal_State                 -0.017061 -0.013408       0.170103   0.053233
# Domain_registeration_length     0.059220  0.011737      -0.075671  -0.017232
# Favicon                         0.937124  0.602297      -0.007488   0.090112
# port                            0.731282  0.653360      -0.002218   0.044265
# HTTPS_token                     0.061783  0.016943      -0.043665   0.397198
# Request_URL                    -0.008739  0.010435       0.092588   0.019123
# URL_of_Anchor                   0.039523  0.008759       0.090748   0.100573
# Links_in_tags                  -0.114062 -0.067538       0.084887  -0.034603
# SFH                            -0.009250  0.004513      -0.021654   0.031815
# Submitting_to_email             0.608216  0.544096      -0.002159   0.059243
# Abnormal_URL                    0.094612  0.020882      -0.032154   0.367459
# Redirect                       -0.028668 -0.011598      -0.029363  -0.186424
# on_mouseover                    0.712133  0.619842       0.006184   0.077082
# RightClick                      0.400979  0.660961      -0.006641   0.025073
# popUpWidnow                     1.000000  0.604315      -0.004516   0.100590
# Iframe                          0.604315  1.000000       0.009625   0.026188
# age_of_domain                  -0.004516  0.009625       1.000000  -0.036706
# DNSRecord                       0.100590  0.026188      -0.036706   1.000000
# web_traffic                    -0.037490 -0.022619       0.085180   0.043320
# Page_Rank                       0.014977  0.015824      -0.142171   0.147995
# Google_Index                   -0.005833  0.007301      -0.030163   0.158990
# Links_pointing_to_page         -0.118402 -0.136874       0.037684  -0.292501
# Statistical_report              0.252179  0.194890      -0.008775   0.139281
# Result                         -0.002868 -0.013429       0.135198   0.081927
#
#                              web_traffic  Page_Rank  Google_Index  \
# having_IP                       0.013970  -0.088005      0.042025
# URL_Length                      0.017214   0.160600      0.000906
# Shortining_Service             -0.054722   0.027620      0.191166
# having_At_Symbol                0.035172  -0.048638      0.052266
# double_slash_redirecting       -0.073786   0.009250      0.216002
# Prefix_Suffix                   0.112270  -0.010107      0.059577
# having_Sub_Domain              -0.001427   0.130962      0.059754
# SSLfinal_State                  0.267394   0.070730      0.092084
# Domain_registeration_length    -0.140463  -0.050998     -0.035604
# Favicon                        -0.046961   0.009195     -0.011916
# port                           -0.025640   0.019871      0.004283
# HTTPS_token                    -0.043082   0.026034      0.141626
# Request_URL                     0.164237   0.051756      0.042176
# URL_of_Anchor                   0.342764   0.090960      0.037725
# Links_in_tags                   0.066325  -0.008366      0.040092
# SFH                             0.063903  -0.003645      0.025839
# Submitting_to_email            -0.015233   0.031347     -0.000257
# Abnormal_URL                   -0.058541   0.017861      0.152228
# Redirect                        0.011229   0.039646      0.057803
# on_mouseover                   -0.031967   0.013234      0.001718
# RightClick                     -0.007967   0.018431      0.000826
# popUpWidnow                    -0.037490   0.014977     -0.005833
# Iframe                         -0.022619   0.015824      0.007301
# age_of_domain                   0.085180  -0.142171     -0.030163
# DNSRecord                       0.043320   0.147995      0.158990
# web_traffic                     1.000000   0.035401     -0.014329
# Page_Rank                       0.035401   1.000000      0.034279
# Google_Index                   -0.014329   0.034279      1.000000
# Links_pointing_to_page         -0.029287  -0.034122     -0.052430
# Statistical_report              0.006416   0.045352     -0.009863
# Result                          0.355581   0.102920      0.121896
#
#                              Links_pointing_to_page  Statistical_report  \
# having_IP                                 -0.339673           -0.020243
# URL_Length                                -0.023217           -0.076373
# Shortining_Service                        -0.190125            0.096561
# having_At_Symbol                          -0.021183           -0.086436
# double_slash_redirecting                  -0.185197            0.081190
# Prefix_Suffix                              0.063379           -0.014781
# having_Sub_Domain                         -0.002065            0.086271
# SSLfinal_State                            -0.006427            0.048559
# Domain_registeration_length                0.130958            0.006768
# Favicon                                   -0.124347            0.271378
# port                                      -0.134893            0.305514
# HTTPS_token                               -0.113749            0.114875
# Request_URL                               -0.073728            0.028565
# URL_of_Anchor                              0.018182            0.072973
# Links_in_tags                              0.012280           -0.090467
# SFH                                       -0.006574           -0.016546
# Submitting_to_email                       -0.027903            0.330597
# Abnormal_URL                              -0.152861            0.219297
# Redirect                                   0.143183           -0.063376
# on_mouseover                              -0.023936            0.218519
# RightClick                                -0.123483            0.148973
# popUpWidnow                               -0.118402            0.252179
# Iframe                                    -0.136874            0.194890
# age_of_domain                              0.037684           -0.008775
# DNSRecord                                 -0.292501            0.139281
# web_traffic                               -0.029287            0.006416
# Page_Rank                                 -0.034122            0.045352
# Google_Index                              -0.052430           -0.009863
# Links_pointing_to_page                     1.000000           -0.002810
# Statistical_report                        -0.002810            1.000000
# Result                                     0.035003            0.068015
#
#                                Result
# having_IP                    0.094027
# URL_Length                   0.059331
# Shortining_Service          -0.066170
# having_At_Symbol             0.050045
# double_slash_redirecting    -0.037758
# Prefix_Suffix                0.344660
# having_Sub_Domain            0.296728
# SSLfinal_State               0.712543
# Domain_registeration_length -0.219960
# Favicon                     -0.003260
# port                         0.033971
# HTTPS_token                 -0.036573
# Request_URL                  0.254572
# URL_of_Anchor                0.696394
# Links_in_tags                0.238802
# SFH                          0.217931
# Submitting_to_email          0.011981
# Abnormal_URL                -0.059860
# Redirect                    -0.027197
# on_mouseover                 0.042180
# RightClick                   0.004880
# popUpWidnow                 -0.002868
# Iframe                      -0.013429
# age_of_domain                0.135198
# DNSRecord                    0.081927
# web_traffic                  0.355581
# Page_Rank                    0.102920
# Google_Index                 0.121896
# Links_pointing_to_page       0.035003
# Statistical_report           0.068015
# Result                       1.000000
#
# [31 rows x 31 columns]
# c:\Users\kalra_m\Anaconda3\lib\site-packages\pandas\core\frame.py:5238: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# pca = PCA(n_components=2)
# x_train_scaled = pca.fit_transform(x_train)

pca = PCA(n_components=2, whiten=True).fit(ds)
x_pca = pca.transform(ds)

# print(x_train_scaled[:10])
# pca2 = PCA(n_components=2)
# x_test_scaled = pca2.fit_transform(x_test)

# %%
import matplotlib.pyplot as plt

# plt.scatter(x_train_scaled, y_train)
# plt.show()
import seaborn as sns


plt.figure(figsize=(12,8))
sns.heatmap(df_comp, cmap="plasma")
print(pca.components_)
# Out:
# [[-0.1984086   0.06962544 -0.19099832 -0.19467446 -0.19304069  0.03693641
#    0.02022478  0.02753974 -0.07553351 -0.38726376 -0.31626106 -0.21034502
#    0.03775739 -0.01249512  0.08845789  0.02477778 -0.34474302 -0.22418966
#    0.0512647  -0.27327456 -0.11113119 -0.39254855 -0.21719422  0.04582753
#   -0.18817704  0.04031019 -0.01634909 -0.04250817  0.08550211 -0.15151159
#    0.01167555]
#  [ 0.02596988 -0.1714236   0.13858459 -0.04840822  0.13057964 -0.15176867
#   -0.18328127 -0.39635118  0.3949955  -0.1149197  -0.12261283  0.12926452
#   -0.43761934 -0.27201648 -0.12643849 -0.14949623 -0.11009593  0.12153584
#   -0.02874552 -0.08450135 -0.0360032  -0.11077381 -0.07658651 -0.21956806
#    0.01945961 -0.22382275 -0.07369003 -0.01521466  0.01420547 -0.04762201
#   -0.22737751]]

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import confusion_matrix

gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)

y_preds = gb.predict(x_test)

print(confusion_matrix(y_test, y_preds))
# Out:
# c:\Users\kalra_m\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [[711  45]
#  [ 38 997]]

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score


train = xgb.DMatrix(x_train, label=y_train)
test = xgb.DMatrix(x_test, label=y_test)
param = {
    'max_depth': 12,
    'eta': 0.33,
    'objective': 'multi:softmax',
    'num_class': 2} 
epochs = 30 

model = xgb.train(param, train, epochs)
y_predsx = model.predict(test)
print(confusion_matrix(y_test, y_predsx))
print(accuracy_score(y_test, y_predsx))

xgbst = xgb.XGBClassifier()
xgbst.fit(x_train, y_train)
y_predsx2 = xgbst.predict(x_test)

print(confusion_matrix(y_test, y_predsx2))
print(accuracy_score(y_test, y_predsx2))
# Out:
# [15:39:20] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softmax' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [[ 733   23]
#  [  26 1009]]
# 0.972640982691234
# [15:39:21] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# c:\Users\kalra_m\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# c:\Users\kalra_m\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [[ 733   23]
#  [  22 1013]]
# 0.9748743718592965
